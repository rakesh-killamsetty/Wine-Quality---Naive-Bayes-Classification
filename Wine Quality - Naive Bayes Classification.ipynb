# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/winequality.csv',sep=';')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
data.shape
# Out:
# (4898, 12)

# %%
data['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
data.groupby('quality').count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                   20                20           20              20
# 4                  163               163          163             163
# 5                 1457              1457         1457            1457
# 6                 2198              2198         2198            2198
# 7                  880               880          880             880
# 8                  175               175          175             175
# 9                    5                 5            5               5
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3               20                   20                    20       20    20
# 4              163                  163                   163      163   163
# 5             1457                 1457                  1457     1457  1457
# 6             2198                 2198                  2198     2198  2198
# ...

# %%
data1=data.loc[(data.quality==5)|(data.quality==7)|(data.quality==8)]
data1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 10              8.1              0.27         0.41            1.45      0.033
# 11              8.6              0.23         0.40            4.20      0.035
# 12              7.9              0.18         0.37            1.20      0.040
# 13              6.6              0.16         0.40            1.50      0.044
# 14              8.3              0.42         0.62           19.25      0.040
# ...             ...               ...          ...             ...        ...
# 4887            6.2              0.41         0.22            1.90      0.023
# 4888            6.8              0.22         0.36            1.20      0.052
# 4892            6.5              0.23         0.38            1.30      0.032
# 4894            6.6              0.32         0.36            8.00      0.047
# 4896            5.5              0.29         0.30            1.10      0.022
#
# ...

# %%
x=data1.drop(['quality'],axis=1)
y=data1['quality']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.23,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB
multi_classifier=GaussianNB()
multi_classifier.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
x_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3878            6.5              0.35         0.31           10.20      0.069
# 1134            7.4              0.41         0.34            4.70      0.042
# 3816            6.8              0.41         0.30            8.80      0.045
# 4651            5.7              0.39         0.25            4.90      0.033
# 4335            7.3              0.19         0.27           13.90      0.057
# ...             ...               ...          ...             ...        ...
# 45              7.4              0.18         0.31            1.40      0.058
# 2893            6.2              0.16         0.34            1.70      0.038
# 390             7.0              0.30         0.38           14.90      0.032
# 1944            6.0              0.45         0.42            1.10      0.051
# 2396            8.4              0.30         0.25           17.75      0.047
#
# ...

# %%
y_test
# Out:
# 3878    5
# 1134    5
# 3816    5
# 4651    7
# 4335    8
#        ..
# 45      7
# 2893    7
# 390     7
# 1944    5
# 2396    5
# Name: quality, Length: 578, dtype: int64

# %%
ypred=multi_classifier.predict(x_test)
ypred
# Out:
# array([5, 5, 5, 7, 5, 7, 5, 7, 5, 5, 5, 5, 8, 5, 5, 7, 7, 7, 5, 5, 7, 7,
#        5, 7, 5, 7, 7, 7, 5, 5, 5, 7, 7, 7, 7, 5, 5, 7, 5, 5, 5, 7, 7, 5,
#        7, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 5, 7, 7, 8, 7, 5, 5, 7, 5,
#        7, 7, 5, 5, 7, 5, 7, 5, 7, 7, 7, 7, 5, 7, 7, 5, 5, 7, 7, 7, 7, 5,
#        7, 5, 7, 7, 7, 7, 7, 5, 5, 5, 7, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 5,
#        7, 5, 7, 5, 7, 7, 5, 5, 5, 7, 5, 7, 7, 7, 7, 7, 5, 7, 7, 5, 7, 5,
#        7, 7, 5, 5, 7, 7, 7, 7, 5, 5, 5, 5, 5, 5, 5, 5, 5, 7, 7, 7, 5, 5,
#        7, 7, 7, 7, 7, 7, 5, 7, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 5, 5, 7, 7,
#        7, 5, 5, 7, 7, 7, 7, 5, 7, 7, 5, 7, 5, 5, 7, 7, 7, 5, 7, 5, 7, 5,
#        5, 5, 5, 7, 5, 7, 5, 7, 7, 5, 7, 5, 5, 5, 5, 5, 7, 5, 5, 7, 5, 5,
#        7, 5, 5, 5, 5, 7, 5, 5, 7, 5, 7, 7, 5, 5, 5, 7, 5, 7, 5, 7, 5, 7,
#        5, 7, 5, 5, 7, 5, 7, 7, 7, 5, 7, 7, 5, 5, 7, 7, 5, 7, 5, 5, 5, 7,
#        5, 5, 7, 5, 7, 7, 5, 7, 5, 5, 5, 5, 5, 5, 5, 7, 7, 7, 5, 5, 7, 7,
# ...

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,ypred)
cm
# Out:
# array([[267,  55,   2],
#        [ 38, 165,   4],
#        [  6,  37,   4]])

# %%
from sklearn.metrics import accuracy_score
cm=accuracy_score(y_test,ypred)
cm
# Out:
# 0.754325259515571

# %%
results=pd.DataFrame(columns=['Actual','Predicted'])
results['Actual']=y_test
results['Predicted']=ypred
results=results.reset_index()
results
# Out:
#      index  Actual  Predicted
# 0     3878       5          5
# 1     1134       5          5
# 2     3816       5          5
# 3     4651       7          7
# 4     4335       8          5
# ..     ...     ...        ...
# 573     45       7          5
# 574   2893       7          8
# 575    390       7          5
# 576   1944       5          5
# 577   2396       5          5
#
# [578 rows x 3 columns]

# %%
cor=data1.corr()
cor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.026492     0.279390
# volatile acidity          -0.026492          1.000000    -0.153564
# citric acid                0.279390         -0.153564     1.000000
# residual sugar             0.119687          0.048351     0.140148
# chlorides                  0.036276          0.085339     0.110583
# free sulfur dioxide       -0.087504         -0.075364     0.121865
# total sulfur dioxide       0.074480          0.107735     0.130040
# density                    0.301103          0.006902     0.188030
# pH                        -0.461680         -0.036835    -0.189796
# sulphates                 -0.034030         -0.032332     0.042542
# alcohol                   -0.164419          0.053404    -0.114555
# quality                   -0.130278         -0.170705    -0.047559
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidth=0.5,cmap='bwr')
# Out:
# <Axes: >
